# %% [markdown]
# # Anatomy of a cranked wing (Cont'd)

# %% [markdown]
# — Agostino De Marco, <font color='darkblue'><i>University of Naples Federico II, Dept. Industrial Engineering</i></font>

# %% [markdown]
# ##### Interlude — setup Python tool first

# %%
# %run ./src/cranked_wing/init.py
# %matplotlib inline
# %run ./src/wing_functions.py

# %% [markdown]
# ## Nomenclature recap

# %%
SVG(filename='./resources/cranked_wing_WEB.svg')

# %% [markdown]
# Retrieve data produced by notebook: `cranked_wing.pynb`

# %%
# https://docs.python.org/3.5/library/shelve.html
import shelve
store = shelve.open('cranked_wing_store', flag='r')

#print('-------- Database content, key => value --------')
#for key in store:
#    print(key, '=> {0}'.format(store[key]))

c_r = store['c_r']
c_k = store['c_k']
c_t = store['c_t']
eps_k = store['eps_k']
eps_t = store['eps_t']
alpha0l_r = store['alpha0l_r']
alpha0l_k = store['alpha0l_k']
alpha0l_t = store['alpha0l_t']
b_k = store['b_k']
b = store['b']
Lambda_le_1 = store['Lambda_le_1']
Lambda_le_2 = store['Lambda_le_2']
# f_chord = store['f_chord']
S_ref = store['S_ref']
c_mac = store['c_mac']
X_le_mac = store['X_le_mac']
Y_mac = store['Y_mac']
alpha0L = store['alpha0L']
store.close()

# %%
Latex(
    r'\begin{array}{rl}'
    +  r'\text{root chord,}\, c_{\mathrm{r}}: & ' + r'{0}'.format(c_r) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{kink chord,}\, c_{\mathrm{k}}: & ' + r'{0}'.format(c_k) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{tip chord,}\, c_{\mathrm{t}}: & ' + r'{0}'.format(c_t) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{semispan, inner panel}\, \frac{1}{2}b_{\mathrm{k}}: & ' + r'{0}'.format(b_k/2) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{semispan,}\, \frac{1}{2}b: & ' + r'{0}'.format(b/2) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{leading edge sweep, inner panel,}\, \Lambda_{\mathrm{le},1}: &' 
    +    r'{0}'.format(Lambda_le_1*180/math.pi) + r'\,\text{deg}'
    +  r'\\'
    +  r'\text{leading edge sweep, outer panel,}\, \Lambda_{\mathrm{le},2}: &' 
    +    r'{0}'.format(Lambda_le_2*180/math.pi) + r'\,\text{deg}'
    +  r'\\'
    +  r'\text{kink section geometric twist,}\, \epsilon_{\mathrm{g,k}}: & ' + r'{0:.4}'.format(eps_k*180/math.pi) + r'\,\text{deg}'
    +  r'\\'
    +  r'\text{tip section geometric twist,}\, \epsilon_{\mathrm{g,t}}: & ' + r'{0:.4}'.format(eps_t*180/math.pi) + r'\,\text{deg}'
    +  r'\\'
    +  r'\text{root profile zero-lift angle of attack,}\, \alpha_{0\ell,\mathrm{r}}: & ' + r'{0:.4}'.format(alpha0l_r*180/math.pi) + r'\,\text{deg}'
    +  r'\\'
    +  r'\text{kink profile zero-lift angle of attack,}\, \alpha_{0\ell,\mathrm{k}}: & ' + r'{0:.4}'.format(alpha0l_k*180/math.pi) + r'\,\text{deg}'
    +  r'\\'
    +  r'\text{tip profile zero-lift angle of attack,}\, \alpha_{0\ell,\mathrm{t}}: & ' + r'{0:.4}'.format(alpha0l_t*180/math.pi) + r'\,\text{deg}'
    +  r'\\[1em] \hline'
    +  r'\text{mean aerodynamic chord (MAC),}\, \bar{c}: & ' + r'{0:.4}'.format(c_mac) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{MAC leading edge longitudinal position,}\, X_{\mathrm{le},\bar{c}}: & ' + r'{0:.4}'.format(X_le_mac) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{MAC leading edge spanwise position,}\, Y_{\bar{c}}: & ' + r'{0:.4}'.format(Y_mac) + r'\,\text{m}'
    +  r'\\'
    +  r'\text{wing zero-lift angle of attack,}\, \alpha_{0L,\mathrm{W}}: & ' + r'{0:.3}'.format(alpha0L*180/math.pi) + r'\,\text{deg}'
    +r'\end{array}'
)
# Out:
# \begin{array}{rl}\text{root chord,}\, c_{\mathrm{r}}: & 5.5\,\text{m}\\\text{kink chord,}\, c_{\mathrm{k}}: & 2.4\,\text{m}\\\text{tip chord,}\, c_{\mathrm{t}}: & 1.5\,\text{m}\\\text{semispan, inner panel}\, \frac{1}{2}b_{\mathrm{k}}: & 7.0\,\text{m}\\\text{semispan,}\, \frac{1}{2}b: & 14.0\,\text{m}\\\text{leading edge sweep, inner panel,}\, \Lambda_{\mathrm{le},1}: &24.0\,\text{deg}\\\text{leading edge sweep, outer panel,}\, \Lambda_{\mathrm{le},2}: &24.0\,\text{deg}\\\text{kink section geometric twist,}\, \epsilon_{\mathrm{g,k}}: & 0.0\,\text{deg}\\\text{tip section geometric twist,}\, \epsilon_{\mathrm{g,t}}: & -2.0\,\text{deg}\\\text{root profile zero-lift angle of attack,}\, \alpha_{0\ell,\mathrm{r}}: & -3.0\,\text{deg}\\\text{kink profile zero-lift angle of attack,}\, \alpha_{0\ell,\mathrm{k}}: & -3.0\,\text{deg}\\\text{tip profile zero-lift angle of attack,}\, \alpha_{0\ell,\mathrm{t}}: & -2.0\,\text{deg}\\[1em] \hline\text{mean aerodynamic chord (MAC),}\, \bar{c}: & 3.436\,\text{m}\\\text{MAC leading edge longitudinal position,}\, X_{\mathrm{le},\bar{c}}: & 2.412\,\text{m}\\\text{MAC leading edge spanwise position,}\, Y_{\bar{c}}: & 5.418\,\text{m}\\\text{wing zero-lift angle of attack,}\, \alpha_{0L,\mathrm{W}}: & -2.54\,\text{deg}\end{array}

# %%
print(f_chord(3, c_r, c_k, c_t, b_k, b, Lambda_le_1, Lambda_le_2))

print('S_ref = {0} m^2'.format(S_ref))
print('c_mac = {0} m'.format(c_mac))
# Out:
# 4.171428571428571
# S_ref = 82.60000000000001 m^2
# c_mac = 3.436158192090395 m

# %% [markdown]
# The following is the planform shape defined by by notebook: `cranked_wing.pynb`

# %%
# plot_planform(c_r, c_k, c_t, b_k, b, Lambda_le_1, Lambda_le_2)
plot_planform(c_r, c_k, c_t, b_k, b, Lambda_le_1, Lambda_le_2, 
              mac=c_mac, X_le_mac=X_le_mac, Y_mac=Y_mac)

# %%
plot_wing_functions(c_r, c_k, c_t, 
                    [], [], [], [], [], # eps_k, eps_t, alpha0l_r, alpha0l_k, alpha0l_t,
                    b_k, b, Lambda_le_1, Lambda_le_2, 
                    ymax = 7, ymin = -4.5,
                    figsize = (11,5), vshift_xaxis=20,
                    f_chord = f_chord)
