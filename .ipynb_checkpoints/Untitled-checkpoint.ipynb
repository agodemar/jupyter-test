# %% [markdown]
# # Welcome to my Jupyter test

# %% [markdown]
# Let's configure our Python

# %%
# %matplotlib notebook

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Now let's try to plot the function $\sin x$ with $x \in [-2\pi,2\pi]$

# %%
x = np.linspace(-2*np.pi,2*np.pi)
line, = plt.plot(x,np.sin(x),'--',linewidth=2)
# Out:
# <img src="data:image/png;base64,...">
